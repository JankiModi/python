# %% [markdown]
# # Reduce fraction

# %%
num = int(input("Enter numerator "))
de = int(input("Enter denominator "))
if(de==0):
    print("ZERO DIVISION ERROR")
else: 
    if(num%de == 0):
        print("REDUCED TO--> ",num//de)
    else:
        newnum = 0
        newde = 0
        for i in range(num,1,-1):
            if((de%i == 0) & (num%i == 0)):
                num = num//i
                de = de//i
        print("REDUCED TO--> ",num,"/",de)

# %% [markdown]
# # Disarium number

# %% [markdown]
# # wap to compute the value of a+aa+aaa+aaaa where a is given by the user

# %%
a = int(input("Enter a number "))
a = a+(a*10+a)+((a*100)+(a*10+a))+((a*1000)+(a*100)+(a*10+a))
print(a)
# Out:
# Enter a number 9
# 11106

# %%
a = int(input("Enter a number "))
n1 = int(f"{a}")
n2 = int(f"{a}{a}")
n3 = int(f"{a}{a}{a}")
n4 = int(f"{a}{a}{a}{a}")
print(n1+n2+n3+n4)
# Out:
# Enter a number 9
# 11106

# %% [markdown]
# # Collatz Conjecture.
# It is generated by repeatedly applying the following rules to integer and to each resulting integer in turn
# 1. If even/2
# 2. If odd * 3 and add +1
#
# This algo is tested and found to always reach one for all positive integers
#
# Create a function that takes two positive integers a & b and returns the a, if it took fewer steps to reach 1 than b

# %%
num1 = int(input("Enter number 1 : "))
num2 = int(input("Enter number 2 : "))
count1 = 0
count2 = 0
temp1 = num1
temp2 = num2
while(num1!=1):
    if(num1%2==0):
        num1 = num1/2
        count1 = count1+1
    else:
        num1 = (num1*3)+1
        count1 = count1+1
while(num2!=1):
    if(num2%2==0):
        num2 = num2/2
        count2 = count2+1
    else:
        num2 = (num2*3)+1
        count2 = count2+1
if(count1>count2):
    print(temp1," took more time to reach 1 than ",temp2)
else:
    print(temp2," took more time to reach 1 than ",temp1)
# Out:
# Enter number 1 : 38
# Enter number 2 : 90
# 38  took more time to reach 1 than  90

# %% [markdown]
# # wap that asks users for an hour between 1 & 12. Ask them to enter AM and PM. Ask them how many hours in the future they want to go.

# %% [markdown]
# # An integer is called square-free, if it is not divisible by any perfect square other than 1. For instance,42 is a square free number, 45
